# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-00ff0b082a7d> in <module>()
# ----> 1 from textblob import TextBlob
#
# ImportError: No module named textblob

# %%
from textblob import TextBlob

# %%
TextBlob('This movie was a great experience, and not disappointing.').sentiment
# Out:
# Sentiment(polarity=0.55, subjectivity=0.725)

# %%
TextBlob('This movie was not a great experience, and disappointing.').sentiment
# Out:
# Sentiment(polarity=-0.5, subjectivity=0.725)

# %%
TextBlob("I'm singin' in the rain,
Just singin' in the rain,
What a glorious feeling,
I'm happy again!
I'm laughing at clouds
So dark up above,
The sun's in my heart and I'm ready for love!
Let the stormy clouds chase
Everyone from the place,
Come on with your rain,
I've got a smile on my face!
I'll walk down the lane
With a happy refrain,
Just singin', singin' in the rain!

Why am I smiling and why do I sing?
Why does December seem sunny as Spring?
Why do I get up each morning to start
Happy and head-up with joy in my heart?
Why is each new task a trifle to do?
Because I am living a life full of you!

Hey, I'm singin' in the rain,
Just singin' in the rain,
What a glorious feeling,
I'm happy again!
I'm laughing at clouds
So dark up above,
The sun's in my heart and I'm ready for love!
Let the stormy clouds chase
Everyone from the place,
Come on with your rain,
I've got a smile on my face!
I'll walk down the lane
With a happy refrain,
Just singin', singin' in the rain!").sentiment
# Out:
#   File "<ipython-input-4-7e99885258a2>", line 1
#     TextBlob("I'm singin' in the rain,
#                                      ^
# SyntaxError: EOL while scanning string literal

# %%
TextBlob('I am singing in the rain, Just singing in the rain, What a glorious feeling, I am happy again!').sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
TextBlob('It is not much of a tail, but I am sort of attached to it.').sentiment
# Out:
# Sentiment(polarity=-0.1, subjectivity=0.2)

# %%
TextBlob('I might have known. After all, one cannot complain. I have my friends. Somebody spoke to me only yesterday. And was it last week or the week before that Rabbit bumped into me and said Bother!. The Social Round. Always something going on.').sentiment
# Out:
# Sentiment(polarity=-0.04166666666666667, subjectivity=0.3833333333333333)

# %%
TextBlob('I have never listened to anyone who criticized my taste in space travel, sideshows or gorillas. When this occurs, I pack up my dinosaurs and leave the room.').sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
TextBlob('To be gorgeous, and high and true and fine and fluffy and moist and sticky and lovely, all you have to do is believe that one is gorgeous and high and true and fine and fluffy and moist and sticky and lovely.').sentiment
# Out:
# Sentiment(polarity=0.3211111111111111, subjectivity=0.6233333333333334)

# %%
TextBlob('Only dull people are brilliant at breakfast').sentiment
# Out:
# Sentiment(polarity=0.2027777777777778, subjectivity=0.8333333333333334)

# %%
TextBlob('There is a sacredness in tears. They are not the mark of weakness, but of power. They speak more eloquently than ten thousand tongues. They are the messengers of overwhelming grief, of deep contrition, and of unspeakable love.').sentiment
# Out:
# Sentiment(polarity=0.11666666666666665, subjectivity=0.45)

# %%
TextBlob('When I despair, I remember that all through history the way of truth and love have always won. There have been tyrants and murderers, and for a time, they can seem invincible, but in the end, they always fall. Think of it--always.').sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.6)

# %%
TextBlob('Why do people have to be this lonely? What's the point of it all? Millions of people in this world, all of them yearning, looking to others to satisfy them, yet isolating themselves. Why? Was the earth put here just to nourish human loneliness?').sentiment
# Out:
#   File "<ipython-input-13-919cbd4f02a3>", line 1
#     TextBlob('Why do people have to be this lonely? What's the point of it all? Millions of people in this world, all of them yearning, looking to others to satisfy them, yet isolating themselves. Why? Was the earth put here just to nourish human loneliness?').sentiment
#                                                          ^
# SyntaxError: invalid syntax

# %%
TextBlob('Why do people have to be this lonely? What is the point of it all? Millions of people in this world, all of them yearning, looking to others to satisfy them, yet isolating themselves. Why? Was the earth put here just to nourish human loneliness?').sentiment
# Out:
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.39999999999999997)

# %%
blob = TextBlob(open("palindromepoem.txt").read())
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# Man, it is hot.
# I erase many men.
# Part animal, can I live?
# Oh, sit in ample hot spots.

# %%
from textblob import TextBlob
blob = TextBlob(open("straka_chapter.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# He recognizes it at the very moment he feels the tug on his trouser leg.
# The monkey, somehow, looks to be in much more vigorous health, and from its toothless mouth comes a vocalization of a sort that S. has never heard from it, free from taunt or condescension or irritation.
# The monkey raises one hand, showing S. a jagged chunk of dark-gray rock, turning it back and forth as if it expects the light from the naked bulb ahead of them to catch one of its facets and make it gleam.
# Then, with surprising strength and dexterity, the monkey wrenches out the loosened bung and sets the black wine spilling, arcing out into the path where it splatters and puddles on the packed earth.
# And the blue-black sheen on the surface of the puddles-this, this is the precious thing that has caught the light.
# He holds out a cupped hand, to taste- Sola���s distress call, and a masculine shout.
# Which came first?
# No broken bones.
# Pain and nothing more.
# ...

# %%
# most negative sentences

# %%
for item in blob.sentences:
    if item.sentiment.polarity < 0:
        print item.replace('\n', ' ')
# Out:
# There may be Agents waiting, but there will be more workers, and they will all carry axes and chisels and any other implements they can use to destroy these barrels and let the black wine- He sniffs: a rank smell cutting through the olfactory fog of blue-black and earth.
# It sounds-and here, S. wonders if the air in the cellars is fogging his mind-as if the monkey is mimicking the run of notes in S���s last whistle-call to Sola.
# When S. whispers, "I don���t understand," the monkey darts ahead to the next barrel and beats the rock against its face, circling the bung.
# The sounds are loud, sharp, and echoing; everyone in the cellars will hear, has already heard.
# S. lurches toward the monkey, grabs at it, but catches only a tuft of fur which comes away in his hand.
# How long has he been wavering drunkenly?
# How long has he been still?
# He leaves behind the monkey, who darts to the next barrel.
# ...

# %%
TextBlob('All graduates should be in regalia and in the robing room by 1:45pm. We will begin lining up by 2:00pm and plan to begin the processional promptly at 2:30pm. Anyone late to the robing room runs the risk of not being part of the processional and subsequently not sitting on the stage with your fellow graduates, so please make sure that you are on time. To get to the robing room, enter through the main entrance of the Clarice, and follow signs to the Dance Theatre, which will be on your right. Volunteers will also be available to direct you. We anticipate that the doors to the Dekelboum will open between 1:30-1:45 for your guests. Please note that all seats for your guests are available on a first-come, first-serve basis, and no specific seat reservations can be made in advance. ').sentiment
# Out:
# Sentiment(polarity=0.15523809523809526, subjectivity=0.4232936507936508)

# %%
TextBlob('Save your skin from the corrosive acids from the mouths of toxic people. Someone who just helped you to speak evil about another person can later help another person to speak evil about you.  ').sentiment
# Out:
# Sentiment(polarity=-0.6666666666666666, subjectivity=0.6666666666666666)

# %%
TextBlob('Pardon me for breathing, which I never do anyway so I don’t know why I bother to say it, oh God, I’m so depressed. Here’s another one of those self-satisfied doors. Life! Don’t talk to me about life.').sentiment
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-a86eb49aa0df> in <module>()
# ----> 1 TextBlob('Pardon me for breathing, which I never do anyway so I don’t know why I bother to say it, oh God, I’m so depressed. Here’s another one of those self-satisfied doors. Life! Don’t talk to me about life.').sentiment
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/blob.pyc in sentiment(self)
#     421         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     422         """
# --> 423         return self.analyzer.analyze(self.raw)
#     424
# ...

# %%
TextBlob('Pardon me for breathing, which I never do anyway so I do not know why I bother to say it, oh God, I am so depressed. Here is another one of those self-satisfied doors. Life! Do not talk to me about life.').sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
TextBlob('The first ten million years were the worst. And the second ten million: they were the worst, too. The third ten million I did not enjoy at all. After that, I went into a bit of a decline.').sentiment
# Out:
# Sentiment(polarity=-0.21666666666666667, subjectivity=0.31481481481481477)

# %%
TextBlob('I only have to talk to somebody and they begin to hate me. Even robots hate me. If you just ignore me I expect I shall probably go away.').sentiment
# Out:
# Sentiment(polarity=-0.5333333333333333, subjectivity=0.9333333333333332)

# %%
TextBlob('Wearily I sit here, pain and misery my only companions. Why stop now just when I am hating it?').sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=1.0)

# %%
TextBlob('It gives me a headache just trying to think down to your level.').sentiment
# Out:
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)

# %%
TextBlob('That ship hated me. It hated me because I talked to it. Simple. I got very bored and depressed, so I went and plugged myself into its external computer feed. I talked to the computer at great length and explained my view of the universe to it.').sentiment
# Out:
# Sentiment(polarity=-0.275, subjectivity=0.6011904761904762)

# %%
TextBlob('Life. Loathe it or ignore it. You cannot like it.').sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
# Straka chapter

# %%
blob = TextBlob(open("straka_chapter.txt").read())
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-a56d960808d2> in <module>()
#       1
#       2 blob = TextBlob(open("straka_chapter.txt").read())
# ----> 3 for item in blob.sentences:
#       4     if item.sentiment.polarity > 0:
#       5         print item.replace('\n', ' ')
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/blob.pyc in sentences(self)
#     612     def sentences(self):
#     613         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 614         return self._create_sentence_objects()
#     615
#     616     @cached_property
#
# ...

# %%
blob = TextBlob(open("straka_chapter.txt").read())
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-32-f98ac4f6d156> in <module>()
#       1 blob = TextBlob(open("straka_chapter.txt").read())
# ----> 2 for item in blob.sentences:
#       3     if item.sentiment.polarity > 0:
#       4         print item.replace('\n', ' ')
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/blob.pyc in sentences(self)
#     612     def sentences(self):
#     613         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 614         return self._create_sentence_objects()
#     615
#     616     @cached_property
#
# ...

# %%
blob = TextBlob(open("SOT288.txt").read())
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-33-386f5182dbcf> in <module>()
#       1 blob = TextBlob(open("SOT288.txt").read())
# ----> 2 for item in blob.sentences:
#       3     if item.sentiment.polarity > 0:
#       4         print item.replace('\n', ' ')
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/blob.pyc in sentences(self)
#     612     def sentences(self):
#     613         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 614         return self._create_sentence_objects()
#     615
#     616     @cached_property
#
# ...

# %%
from textblob import TextBlob

# %%
blob = TextBlob(open("dorst_chapter.txt").read())
for item in blob.sentences:
    if item.sentiment.polarity < 0:
        print item.replace('\n', ' ')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-37-2e9111b837cb> in <module>()
#       1 blob = TextBlob(open("dorst_chapter.txt").read())
# ----> 2 for item in blob.sentences:
#       3     if item.sentiment.polarity < 0:
#       4         print item.replace('\n', ' ')
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/DLT/anaconda/lib/python2.7/site-packages/textblob/blob.pyc in sentences(self)
#     612     def sentences(self):
#     613         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 614         return self._create_sentence_objects()
#     615
#     616     @cached_property
#
# ...

# %%
from textblob import TextBlob
blob = TextBlob(open("straka_chapter.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# He recognizes it at the very moment he feels the tug on his trouser leg.
# The monkey, somehow, looks to be in much more vigorous health, and from its toothless mouth comes a vocalization of a sort that S. has never heard from it, free from taunt or condescension or irritation.
# The monkey raises one hand, showing S. a jagged chunk of dark-gray rock, turning it back and forth as if it expects the light from the naked bulb ahead of them to catch one of its facets and make it gleam.
# Then, with surprising strength and dexterity, the monkey wrenches out the loosened bung and sets the black wine spilling, arcing out into the path where it splatters and puddles on the packed earth.
# And the blue-black sheen on the surface of the puddles-this, this is the precious thing that has caught the light.
# He holds out a cupped hand, to taste- Sola���s distress call, and a masculine shout.
# Which came first?
# No broken bones.
# Pain and nothing more.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity < 0:
        print item.replace('\n', ' ')
# Out:
# There may be Agents waiting, but there will be more workers, and they will all carry axes and chisels and any other implements they can use to destroy these barrels and let the black wine- He sniffs: a rank smell cutting through the olfactory fog of blue-black and earth.
# It sounds-and here, S. wonders if the air in the cellars is fogging his mind-as if the monkey is mimicking the run of notes in S���s last whistle-call to Sola.
# When S. whispers, "I don���t understand," the monkey darts ahead to the next barrel and beats the rock against its face, circling the bung.
# The sounds are loud, sharp, and echoing; everyone in the cellars will hear, has already heard.
# S. lurches toward the monkey, grabs at it, but catches only a tuft of fur which comes away in his hand.
# How long has he been wavering drunkenly?
# How long has he been still?
# He leaves behind the monkey, who darts to the next barrel.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0.8:
        print item.replace('\n', ' ')

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0.7:
        print item.replace('\n', ' ')

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0.6:
        print item.replace('\n', ' ')
# Out:
# These are the footsteps of a man who walks unafraid, who is certain he will have the best of any opposition he encounters.

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.5:
        print item.replace('\n', ' ')

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.4:
        print item.replace('\n', ' ')
# Out:
# But they are here, and it is because he failed them.

# %%
from textblob import TextBlob
blob = TextBlob(open("SOT288.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# And when, another fifty yards along a straight, downward-sloping corridor, he turn to his left and finds Sola.
# He watches her face - her open and steady face - and he knows that she can see through him.
# He finds himself repeating her words without conscious effort.
# Then another - a high scream of deranged glee.
# The monkey seems to have re-acquired the piss-and-vinegar of its youth and is scampering wildly between and under barrels, pulling out the bungs and tossing them far away.
# A pull of the trigger right now would erase both of them, immediately and irrevocably.
# [/i] Sola slips S. a lighter, a naphta lighter, the most powerful weapon that anyone in the cellar possesses.
# Perhaps he sees the cool embrace of self-destruction for a noble end in them both.
# He lowers the gun, tosses it to the ground near S.'s feet.
# This isn't a threat, he reassures himself, and besides, he'd better go see what his damned son has gotten them into now.

# %%
from textblob import TextBlob
blob = TextBlob(open("P&P.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
#  of a good fortune, must be in want of a wife.a single man in possession
#  of some one or other of their daughters.considered the rightful property
#  ���Oh!he married or single?���next week.���d some of his servants are to
# Single, my dear, to be sure!
#  five thousand a year.fortune; four or
#  ���How so? thing for our girls!���
#  ���I see no occasion for that. them, and therefore you must visit him as
#  ���My dear, you flatter me. Mr. Bingley may like you the best of there
#  I do not pretend to be anything extraordinary now.
#  ���But consider your daughters., I assure you.���ingley when he comes into
#  ���I desire you will do no such thing.tle Lizzy.��� of the girls; though
#  good-humoured as Lydia.he is not half so handsome as Jane, nor half so
#  ���Mr.ess than her sisters.���her girls; but Lizzy has something more of are
# Bennet, how _can_ you abuse your own children in such a way?
# I have a high respect for your nerves.
#  are my old friends.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0.9:
        print item.replace('\n', ' ')
# Out:
#  shut.
#  her twice!
#  great!
#  I assure you.
#  ���I am perfectly convinced by it that Mr. Darcy has no defect.
#  his comfort, appeared very remarkable.
#  his father was--have done this.
# _That_ would be the greatest misfortune of all!
# How wonderfully these sort of things occur!
#  good-naturedly engaged Mr. Collins���s conversation to herself.
#  perfect as plan could be.
#  Miss Bingley.
#  was done for the best.
#  the world to that sort of thing.
#  excellent manager, I dare say.
# ���His father was an excellent man,��� said Mrs. Gardiner.
# ���He is perfectly well behaved, polite, and unassuming,��� said her uncle.
#  whose northern aspect rendered it delightful for summer.
#  distress, my dear Lizzy, is very great.
#  not know which are the best warehouses.
#  Jane then took it from her pocket-book, and gave it to Elizabeth.
# ���This is delightful indeed!
# I am so happy!
#  to come to Netherfield, if he likes it.
#  ���Good gracious!
#  happy!
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity < 0.5:
        print item.replace('\n', ' ')
# Out:
#  of a good fortune, must be in want of a wife.a single man in possession
#  of some one or other of their daughters.considered the rightful property
#  Mr. Bennet replied that he had not.ady to him one day, ���have you heard that
#  Mr. Bennet made no answer.he; ���for Mrs. Long has just been here, and she
# ���Do you not want to know who has taken it?��� cried his wife impatiently.
#  This was invitation enough.d I have no objection to hearing it.���
#  ���Oh!he married or single?���next week.���d some of his servants are to
# Single, my dear, to be sure!
#  five thousand a year.fortune; four or
#  ���How so? thing for our girls!���
#  ���My dear Mr. Bennet,��� replied his wife, ���how can you be so tiresome!
#  ���Design! his design in settling here?���ng one of them.���
# Nonsense, how can you talk so!
#  ���I see no occasion for that. them, and therefore you must visit him as
#  I do not pretend to be anything extraordinary now.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.6:
        print item.replace('\n', ' ')
# Out:
#  ���My dear Mr. Bennet,��� replied his wife, ���how can you be so tiresome!
#  ���I am sick of Mr. Bingley,��� cried his wife.
#  standing about by yourself in this stupid manner.
#  supercilious; on the contrary, he was all attention to everybody.
#  she had no conversation, no style, no beauty.
#  their dear friend���s vulgar relations.
#  declared that they were miserable.
#  must confess.
#  to be impartial.
# Everybody is disgusted with his pride.
#  my spirits will not bear solitude.
# I had not thought so very ill of him.
#  impossible.
#  a man agreeable whom one is determined to hate!
#  to accept them is absolutely impossible.
#  Charlotte���s reply was spared by the entrance of Jane and Elizabeth.
# I am sick of them all.
#  Lady Catherine.
# Their table was superlatively stupid.
#  ���You shall hear then--but prepare yourself for something very dreadful.
#  his hand.
#  dreadful.
#  me, and I had no difficulty in believing it, were exceedingly bad.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.9:
        print item.replace('\n', ' ')
# Out:
#  she had no conversation, no style, no beauty.
# Everybody is disgusted with his pride.
#  a man agreeable whom one is determined to hate!
#  ���You shall hear then--but prepare yourself for something very dreadful.
#  dreadful.
#  very bad!
#  between her and her family was rather noisy than pathetic.
# It would be dreadful!
#  ���Oh, yes!--that, that is the worst of all.
#  to send her away!
#  dreadfully racked as _yours_ seems to have been.
#  an evil which had been brought on by himself.
#  ���Hate you!
#  and looking, and thinking for _your_ approbation alone.

# %%
from textblob import TextBlob
blob = TextBlob(open("SOT289.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# destroyed, and it is worth preserving.
# [/i] And his greatest revelation comes to him.
# V��voda only needs to write using half of a barrel to make it his own.
# It would be his gift to those he drew the ink from in the first place.
# He notices light, finally light.
# His first thought is of Sola and he shoves the door open.
# There is a click as a revolver hammer locks into place and S. is suddenly aware of pressure on the back of his head.
# S. is shoved face first into the desk, the pressure on the back of his head is ever present.
# Somewhere distant there are the sounds of a scuffle and the pistol fires several more times before the room falls silent.
# A voice, he can barely hear a voice.
# He unties the lines and helps draw up oars to lead the ship to a star-filled sky, to a warm wind blowing from the southeast, to open water.

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.5:
        print item.replace('\n', ' ')

# %%
from textblob import TextBlob
blob = TextBlob(open("SOT290.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.5:
        print item.replace('\n', ' ')
# Out:
# She is burned, badly burned, but she still breathes smokey air despite her wounds.

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# A shot right now would erase Sola, immediately and irrevocably.
# But it could also light everything.
# Perhaps he sees what S. saw in her face ��� that cool embrace of self-destruction for a noble end.
# S. sees a man who is willing to do anything to protect his choices, his life, and the life of his son.
# He would be back with water, but S. knew the flames would be too much by then.
# The bright roaring flame that V��voda had fueled and she had lit.
# The fires are too hot, too bright.
# Does V��voda wait at the top with a gun readied?
# She tries to say more but her words are unrecognizable.
# S. squeezes her gently and takes one step at a time.
# He carries her up through the higher level of the cellar and across the lawn to the servants pavilion and down the dry well and through the engirding passage and into the grotto and back to the water.
# [i]What begins at the water shall end there, and what ends there shall once more begin.
# The smoke would make sure of that.
# ...

# %%
from textblob import TextBlob
blob = TextBlob(open("SOT290.txt").read().decode('ascii', errors="replace"))

# %%
for item in blob.sentences:
    if item.sentiment.polarity > 0:
        print item.replace('\n', ' ')
# Out:
# A shot right now would erase Sola, immediately and irrevocably.
# But it could also light everything.
# Perhaps he sees what S. saw in her face ��� that cool embrace of self-destruction for a noble end.
# S. sees a man who is willing to do anything to protect his choices, his life, and the life of his son.
# He would be back with water, but S. knew the flames would be too much by then.
# The bright roaring flame that V��voda had fueled and she had lit.
# The fires are too hot, too bright.
# Does V��voda wait at the top with a gun readied?
# She tries to say more but her words are unrecognizable.
# S. squeezes her gently and takes one step at a time.
# He carries her up through the higher level of the cellar and across the lawn to the servants pavilion and down the dry well and through the engirding passage and into the grotto and back to the water.
# [i]What begins at the water shall end there, and what ends there shall once more begin.
# The smoke would make sure of that.
# ...

# %%
for item in blob.sentences:
    if item.sentiment.polarity < -0.5:
        print item.replace('\n', ' ')
# Out:
# She is burned, badly burned, but she still breathes smokey air despite her wounds.
